# %% [markdown]
# Course : MACHINE LEARNING WITH DEPLOYMENT AND DEEP LEARNING

# %% [markdown]
# Matplotlib Assignment - By Subham Bagchi

# %% [markdown]
# We have the min and max temperatures in a city In India for each months of the year. We would like to find a function to describe this and show it graphically, the dataset given below. Task:
#
# fitting it to the periodic function
# plot the fit Data
#   Max = 39, 41, 43, 47, 49, 51, 45, 38, 37, 29, 27, 25
#   Min = 21, 23, 27, 28, 32, 35, 31, 28, 21, 19, 17, 18

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
max_temp = np.array([39,41,43,47,49,51,45,38,37,29,27,25])
min_temp = np.array([21,23,27,28,32,35,31,28,21,19,17,18])

# %%
months=np.arange(12)

# %%
plt.figure(figsize=(8,6))
plt.plot(months,max_temp,'go')
plt.plot(months,min_temp,'co')
plt.xlabel('Months')
plt.ylabel('Max and Min Temperatures')
# Out:
# Text(0, 0.5, 'Max and Min Temperatures')

# %% [markdown]
# Fitting it to a periodic function

# %%
from scipy import optimize
def yearly_temps(times, avg, ampl, time_offset):
    return (avg
            + ampl * np.cos((times + time_offset) * 2 * np.pi / times.max()))
res_max, cov_max = optimize.curve_fit(yearly_temps, months, max_temp, [40, 20, 0])
res_min, cov_min = optimize.curve_fit(yearly_temps, months, min_temp, [-40, 20, 0])

# %% [markdown]
# Plotting the fit

# %%
days = np.linspace(0,12,num=365)
plt.figure(figsize=(8,6))
plt.plot(months,max_temp,'go')
plt.plot(days, yearly_temps(days, *res_max), 'm-')
plt.plot(months, min_temp, 'co')
plt.plot(days, yearly_temps(days, *res_min), 'y-')
plt.xlabel('Month')
plt.ylabel('Temperature ($^\circ$C)')
plt.show()

# %% [markdown]
# Matplotlib:
#                 This assignment is for visualization using matplotlib:
# data to use:
#               url=https://raw.githubusercontent.com/Geoyi/Cleaning-Titanic-Data/master/titanic_original.csv
#
#
# titanic = pd.read_csv(url)
# Charts to plot:
# 1. Create a pie chart presenting the male/female proportion
# 2. Create a scatterplot with the Fare paid and the Age, differ the plot color by gender

# %%
import pandas as pd

# %%
url='https://raw.githubusercontent.com/Geoyi/Cleaning-Titanic-Data/master/titanic_original.csv'

# %%
titanic = pd.read_csv(url)
titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton  female
# 1     1.0       1.0                   Allison, Master. Hudson Trevor    male
# 2     1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000    0.0    0.0   24160  211.3375       B5        S    2    NaN
# 1   0.9167    1.0    2.0  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %% [markdown]
# Create a pie chart presenting the male/female proportion

# %%
p = round((titanic['sex'].value_counts())/len(titanic)*100,2)
pd.DataFrame(p)
# Out:
#           sex
# male    64.35
# female  35.57

# %%
labels = ['male','female']
fig1,ax1 = plt.subplots()
plt.title('Male/Female Proportion')
ax1.pie(titanic['sex'].value_counts(),labels=labels,autopct='%1.1f%%',shadow=True)
plt.show()

# %% [markdown]
# Create a scatterplot with the Fare paid and the Age, differ the plot color by gender

# %%
t = titanic[titanic.sex=='male']['fare']

# %%
t.head(2)
# Out:
# 1    151.55
# 3    151.55
# Name: fare, dtype: float64

# %%
f = titanic[titanic.sex=='female']['fare']

# %%
f.head(2)
# Out:
# 0    211.3375
# 2    151.5500
# Name: fare, dtype: float64

# %%
t1 = titanic[titanic.sex=='male']['age']

# %%
t1.head(2)
# Out:
# 1     0.9167
# 3    30.0000
# Name: age, dtype: float64

# %%
f1 = titanic[titanic.sex=='female']['age']

# %%
f1.head(2)
# Out:
# 0    29.0
# 2     2.0
# Name: age, dtype: float64

# %%
plt.figure(figsize=(8,6))
plt.scatter(t1,t,c = 'blue',label='male')
plt.scatter(f1,f,c= 'orange',label='female')
plt.xlabel("Age")
plt.ylabel("Fare Paid")
plt.legend()
plt.show()
